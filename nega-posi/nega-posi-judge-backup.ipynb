# %% [markdown]
# ### 現在(8/21)の目標 : このプログラムの関数化

# %%
#natto-py から MeCabをインポート
from natto import MeCab
import re
nm=MeCab()

# %%
tweet="高専楽しすぎワロタｗｗｗｗｗ男女でワイワイ…┏(;^o^)┓あれ…？(;^o^)おんな？！(^o^;≡;^o^)女どこ？！(;^o^)女がいない…≡┏( ^o^)┓女の子どこ！≡┗( ^o^)┛おんな！≡┏( ^o^)┓おんな！≡┗( ^o^)┛じゃあ俺が女の子になるっ！"

# %%
tweet=input('>')
# Out:
# >阪神タイガースは、今シーズンもう諦めて、来季以降を見据えて、若手を起用して戦おうよ！！ この状況が逆にチャンスやん

# %%
# print(nm.parse(text))
wakati=nm.parse(tweet).split('\n')
wlist=[]
for ws in wakati:
    ws=ws.split(',')
    wlist.append(ws)
print(wlist)
# Out:
# [['阪神タイガース\t名詞', '固有名詞', '組織', '*', '*', '*', '阪神タイガース', 'ハンシンタイガース', 'ハンシンタイガース'], ['は\t助詞', '係助詞', '*', '*', '*', '*', 'は', 'ハ', 'ワ'], ['、\t記号', '読点', '*', '*', '*', '*', '、', '、', '、'], ['今\t接頭詞', '名詞接続', '*', '*', '*', '*', '今', 'コン', 'コン'], ['シーズン\t名詞', '一般', '*', '*', '*', '*', 'シーズン', 'シーズン', 'シーズン'], ['もう\t副詞', '一般', '*', '*', '*', '*', 'もう', 'モウ', 'モー'], ['諦め\t動詞', '自立', '*', '*', '一段', '連用形', '諦める', 'アキラメ', 'アキラメ'], ['て\t助詞', '接続助詞', '*', '*', '*', '*', 'て', 'テ', 'テ'], ['、\t記号', '読点', '*', '*', '*', '*', '、', '、', '、'], ['来季\t名詞', '一般', '*', '*', '*', '*', '来季', 'ライキ', 'ライキ'], ['以降\t名詞', '副詞可能', '*', '*', '*', '*', '以降', 'イコウ', 'イコー'], ['を\t助詞', '格助詞', '一般', '*', '*', '*', 'を', 'ヲ', 'ヲ'], ['見据え\t動詞', '自立', '*', '*', '一段', '連用形', '見据える', 'ミスエ', 'ミスエ'], ['て\t助詞', '接続助詞', '*', '*', '*', '*', 'て', 'テ', 'テ'], ['、\t記号', '読点', '*', '*', '*', '*', '、', '、', '、'], ['若手\t名詞', '一般', '*', '*', '*', '*', '若手', 'ワカテ', 'ワカテ'], ['を\t助詞', '格助詞', '一般', '*', '*', '*', 'を', 'ヲ', 'ヲ'], ['起用\t名詞', 'サ変接続', '*', '*', '*', '*', '起用', 'キヨウ', 'キヨー'], ['し\t動詞', '自立', '*', '*', 'サ変・スル', '連用形', 'する', 'シ', 'シ'], ['て\t助詞', '接続助詞', '*', '*', '*', '*', 'て', 'テ', 'テ'], ['戦お\t動詞', '自立', '*', '*', '五段・ワ行促音便', '未然ウ接続', '戦う', 'タタカオ', 'タタカオ'], ['う\t助動詞', '*', '*', '*', '不変化型', '基本形', 'う', 'ウ', 'ウ'], ['よ\t助詞', '終助詞', '*', '*', '*', '*', 'よ', 'ヨ', 'ヨ'], ['！\t記号', '一般', '*', '*', '*', '*', '！', '！', '！'], ['！\t記号', '一般', '*', '*', '*', '*', '！', '！', '！'], ['この\t連体詞', '*', '*', '*', '*', '*', 'この', 'コノ', 'コノ'], ['状況\t名詞', '一般', '*', '*', '*', '*', '状況', 'ジョウキョウ', 'ジョーキョー'], ['が\t助詞', '格助詞', '一般', '*', '*', '*', 'が', 'ガ', 'ガ'], ['逆\t名詞', '一般', '*', '*', '*', '*', '逆', 'ギャク', 'ギャク'], ['に\t助詞', '格助詞', '一般', '*', '*', '*', 'に', 'ニ', 'ニ'], ['チャンス\t名詞', '一般', '*', '*', '*', '*', 'チャンス', 'チャンス', 'チャンス'], ['やん\t助動詞', '*', '*', '*', '不変化型', '基本形', 'やん', 'ヤン', 'ヤン'], ['EOS']]

# %%
#########前処理マン#######
for w in wlist:
    if '名詞' in w[0]:
        w[0]='名詞'
    elif '形容詞' in w[0]:
        w[0]='形容詞'
    elif '副詞' in w[0]:
        w[0]='副詞'
    elif '動詞' in w[0]:
        w[0]='動詞'
    else:
        w[0]=w[0]
del wlist[len(wlist)-1]
########################

# %%
print(wlist)
# Out:
# [['名詞', '固有名詞', '組織', '*', '*', '*', '阪神タイガース', 'ハンシンタイガース', 'ハンシンタイガース'], ['は\t助詞', '係助詞', '*', '*', '*', '*', 'は', 'ハ', 'ワ'], ['、\t記号', '読点', '*', '*', '*', '*', '、', '、', '、'], ['今\t接頭詞', '名詞接続', '*', '*', '*', '*', '今', 'コン', 'コン'], ['名詞', '一般', '*', '*', '*', '*', 'シーズン', 'シーズン', 'シーズン'], ['副詞', '一般', '*', '*', '*', '*', 'もう', 'モウ', 'モー'], ['動詞', '自立', '*', '*', '一段', '連用形', '諦める', 'アキラメ', 'アキラメ'], ['て\t助詞', '接続助詞', '*', '*', '*', '*', 'て', 'テ', 'テ'], ['、\t記号', '読点', '*', '*', '*', '*', '、', '、', '、'], ['名詞', '一般', '*', '*', '*', '*', '来季', 'ライキ', 'ライキ'], ['名詞', '副詞可能', '*', '*', '*', '*', '以降', 'イコウ', 'イコー'], ['を\t助詞', '格助詞', '一般', '*', '*', '*', 'を', 'ヲ', 'ヲ'], ['動詞', '自立', '*', '*', '一段', '連用形', '見据える', 'ミスエ', 'ミスエ'], ['て\t助詞', '接続助詞', '*', '*', '*', '*', 'て', 'テ', 'テ'], ['、\t記号', '読点', '*', '*', '*', '*', '、', '、', '、'], ['名詞', '一般', '*', '*', '*', '*', '若手', 'ワカテ', 'ワカテ'], ['を\t助詞', '格助詞', '一般', '*', '*', '*', 'を', 'ヲ', 'ヲ'], ['名詞', 'サ変接続', '*', '*', '*', '*', '起用', 'キヨウ', 'キヨー'], ['動詞', '自立', '*', '*', 'サ変・スル', '連用形', 'する', 'シ', 'シ'], ['て\t助詞', '接続助詞', '*', '*', '*', '*', 'て', 'テ', 'テ'], ['動詞', '自立', '*', '*', '五段・ワ行促音便', '未然ウ接続', '戦う', 'タタカオ', 'タタカオ'], ['動詞', '*', '*', '*', '不変化型', '基本形', 'う', 'ウ', 'ウ'], ['よ\t助詞', '終助詞', '*', '*', '*', '*', 'よ', 'ヨ', 'ヨ'], ['！\t記号', '一般', '*', '*', '*', '*', '！', '！', '！'], ['！\t記号', '一般', '*', '*', '*', '*', '！', '！', '！'], ['この\t連体詞', '*', '*', '*', '*', '*', 'この', 'コノ', 'コノ'], ['名詞', '一般', '*', '*', '*', '*', '状況', 'ジョウキョウ', 'ジョーキョー'], ['が\t助詞', '格助詞', '一般', '*', '*', '*', 'が', 'ガ', 'ガ'], ['名詞', '一般', '*', '*', '*', '*', '逆', 'ギャク', 'ギャク'], ['に\t助詞', '格助詞', '一般', '*', '*', '*', 'に', 'ニ', 'ニ'], ['名詞', '一般', '*', '*', '*', '*', 'チャンス', 'チャンス', 'チャンス'], ['動詞', '*', '*', '*', '不変化型', '基本形', 'やん', 'ヤン', 'ヤン']]

# %%
text = "アルバイト・パート本社は明治４２年創業、大阪中央郵便局内に職員食堂として開業。以後順調に業績を延ばし、全国２０ケ所に営業所を開設している。"

# %%
tweet = "アルバイト・パート本社は明治４２年創業、大阪中央郵便局内に職員食堂として開業。以後順調に業績を延ばし、全国２０ケ所に営業所を開設している。"

# %%
tweet="部屋が汚いんじゃない・・・逆に考えるんだ。世界が美しすぎるんだと・・・"

# %%
# word_list=[]
# #MeCabNodeに分解
# #MeCabNodeはくだけた文章には使えないっぽい⇨普通にnm.parseでやった方がよさそう
# with MeCab('-F%m,%f[0],%h,%f[8]') as nm:
#     for n in nm.parse(tweet, as_nodes=True):
#         #print(n.feature)
#         txt=str(n.feature)
#         word_info=txt.split(',')
#         word_list.append(word_info)
# del(word_list[len(word_list)-1])
# print(word_list)

# %%
########以下の品詞のみ抜き出す#########
judge_list=[]
for word in wlist:
    if(word[6] != '*'):
        if ((word[0] == "名詞" ) or (word[0] == "形容詞") or (word[0] == "動詞") or (word[0] == "副詞")) :
             judge_list.append(word[6])
print(judge_list)
#################################
# Out:
# ['阪神タイガース', 'シーズン', 'もう', '諦める', '来季', '以降', '見据える', '若手', '起用', 'する', '戦う', 'う', '状況', '逆', 'チャンス', 'やん']

# %%
############辞書の読み込み#############
f = open('pn_ja.txt')
data1 = f.read()  # ファイル終端まで全て読んだデータを返す
data1=data1.replace(':',',')
f.close()
lines=data1.split('\n')
#平仮名も残しておいた方がいい．必ずしも感じとは限らない
lines[0:5]
###################################
# Out:
# ['優れる,すぐれる,動詞,1',
#  '良い,よい,形容詞,0.999995',
#  '喜ぶ,よろこぶ,動詞,0.999979',
#  '褒める,ほめる,動詞,0.999979',
#  'めでたい,めでたい,形容詞,0.999645']

# %%
##########点数辞書#############
word_to_score=[]
for line in lines:
    word=line.split(',')
    word_to_score.append(word)    
del word_to_score[55125]

word_to_score[10:20]
#############################
# Out:
# [['功績', 'こうせき', '名詞', '0.999104'],
#  ['賞', 'しょう', '名詞', '0.998943'],
#  ['嬉しい', 'うれしい', '形容詞', '0.998871'],
#  ['喜び', 'よろこび', '名詞', '0.998861'],
#  ['才知', 'さいち', '名詞', '0.998771'],
#  ['徳', 'とく', '名詞', '0.998745'],
#  ['才能', 'さいのう', '名詞', '0.998699'],
#  ['素晴らしい', 'すばらしい', '形容詞', '0.998617'],
#  ['芳しい', 'かんばしい', '形容詞', '0.998578'],
#  ['称える', 'たたえる', '動詞', '0.998576']]

# %%
########要素がしっかりあるか確認#####
for w_s in word_to_score:
    if(len(w_s)!=4):
        print(len(w_s))
        print(word_to_score.index(w_s))
##############################

# %%
############点数計算############
score=0
#setにして単語検索でもいける
for word in judge_list:
    print(word)
    for w_s in word_to_score:
        if w_s[0]==word or w_s[1]==word :
            score+=float(w_s[3])
            print('単語:'+w_s[3]+',合計:'+str(score))
            break
print(score/len(judge_list))
###############################
# Out:
# 阪神タイガース
# シーズン
# 単語:-0.184022,合計:-0.184022
# もう
# 単語:-0.205726,合計:-0.389748
# 諦める
# 単語:0.0123167,合計:-0.37743129999999997
# 来季
# 以降
# 単語:-0.569431,合計:-0.9468623
# 見据える
# 単語:-0.435069,合計:-1.3819313
# 若手
# 単語:0.959358,合計:-0.42257329999999993
# 起用
# 単語:-0.449557,合計:-0.8721302999999999
# する
# 単語:-0.492314,合計:-1.3644443
# 戦う
# 単語:-0.642608,合計:-2.0070523
# う
# 単語:-0.345261,合計:-2.3523132999999996
# 状況
# 逆
# 単語:-0.520676,合計:-2.8729892999999995
# チャンス
# 単語:0.97716,合計:-1.8958292999999995
# やん
# -0.11848933124999997
